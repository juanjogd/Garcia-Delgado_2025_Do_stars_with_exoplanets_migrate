# %% [markdown]
# # Presets

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import astropy.units as u
from astropy.coordinates import SkyCoord, match_coordinates_sky
from astroquery.gaia import Gaia
from matplotlib.patches import Circle

# %%
# exoplanet_catalogue = pd.read_csv('exoplanet_catalogue.csv')  # Exoplanet catalogue from local CSV
exoplanet_catalogue = pd.read_csv('exoplanet_catalogue_2.csv')  # Exoplanet catalogue from local CSV
exoplanet_catalogue = exoplanet_catalogue.dropna(subset=['ra', 'dec'])  # Remove rows with missing RA/DEC
print(f"Exoplanet catalogue loaded with {len(exoplanet_catalogue)} entries.")
# Out:
# Exoplanet catalogue loaded with 7379 entries.

# %%
# num_exoplanets = 1000
num_exoplanets = 100
subset_catalogue = exoplanet_catalogue.iloc[:num_exoplanets]
threshold = 10 * u.arcsec
# threshold = 2 * u.arcsec
gaia_results = []

for index, row in subset_catalogue.iterrows():
    ra = row['ra']
    dec = row['dec']
    exoplanet_coord = SkyCoord(ra=ra * u.deg, dec=dec * u.deg, frame='icrs')
    
    # Query Gaia around the exoplanet's coordinates with the threshold
    query = Gaia.query_object_async(
        coordinate=exoplanet_coord, 
        radius=threshold
    )

    gaia_results.append(query)

gaia_stars = pd.concat([result.to_pandas() for result in gaia_results], ignore_index=True)

print(f"Processed {num_exoplanets} exoplanets.")
print(f"Found {len(gaia_stars)} stars in Gaia.")
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# Processed 100 exoplanets.
# Found 98 stars in Gaia.

# %%
import time
from astropy.table import vstack

# Parameters
num_exoplanets = len(exoplanet_catalogue)
batch_size = 250
threshold = 2 * u.arcsec

# Subset of the catalogue
subset_catalogue = exoplanet_catalogue.iloc[:num_exoplanets]
gaia_results = []

# Function to query Gaia in batches
def query_gaia_batch(batch):
    batch_results = []
    for index, row in batch.iterrows():
        ra = row['ra']
        dec = row['dec']
        exoplanet_coord = SkyCoord(ra=ra * u.deg, dec=dec * u.deg, frame='icrs')

        retries = 3
        while retries > 0:
            try:
                # print(f"Índice {index}: Enviando consulta...")
                result = Gaia.query_object_async(
                    coordinate=exoplanet_coord,
                    radius=threshold
                )
                batch_results.append(result)
                print(f"Índice {index}: Consulta finalizada.")
                break  # éxito, salir del while
            except Exception as e:
                print(f"Error en índice {index}: {e}")
                retries -= 1
                time.sleep(5)

        # time.sleep(1)

    return batch_results

# Processing in batches
for start in range(0, num_exoplanets, batch_size):
    end = min(start + batch_size, num_exoplanets)
    batch = subset_catalogue.iloc[start:end]
    print(f"Procesando lote {start} a {end}...")

    batch_results = query_gaia_batch(batch)
    gaia_results.extend(batch_results)

    print(f"Finalizado lote {start} a {end}. Esperando antes del siguiente lote...")
    time.sleep(5)  # pausa entre lotes para no sobrecargar

# Convertir todos los resultados a un DataFrame de pandas
gaia_stars = pd.concat([res.to_pandas() for res in gaia_results], ignore_index=True)

print(f"Procesados {num_exoplanets} exoplanetas.")
print(f"Encontradas {len(gaia_stars)} estrellas en Gaia.")
# Out:
# Procesando lote 0 a 250...
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 0: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 1: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 2: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 3: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 4: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 5: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 6: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 8: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 9: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 10: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 11: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 12: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 14: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 15: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 16: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 17: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 18: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 19: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 20: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 21: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 22: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 23: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 24: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 25: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 26: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 27: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 28: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 29: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 30: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 31: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 32: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 33: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 34: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 35: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 36: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 37: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 38: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 39: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 40: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 41: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 42: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 43: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 44: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 45: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 46: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 47: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 48: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 49: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 50: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 51: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 52: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 53: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 54: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 55: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 56: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 57: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 58: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 59: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 60: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 61: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 62: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 63: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 64: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 65: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 66: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 67: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 68: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 69: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 70: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 71: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 72: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 73: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 74: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 75: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 76: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 77: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 78: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 79: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 80: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 81: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 82: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 83: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 84: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 85: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 86: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 87: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 88: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 89: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 90: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 91: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 92: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 93: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 94: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 95: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 96: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 97: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 98: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 99: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 100: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 101: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 102: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 103: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 104: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 105: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 106: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 107: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 108: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 109: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 110: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 111: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 112: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 113: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 114: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 115: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 116: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 117: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 118: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 119: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 120: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 121: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 122: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 123: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 124: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 125: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 126: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 127: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 128: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 129: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 130: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 131: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 132: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 133: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 134: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 135: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 136: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 137: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 138: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 139: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 140: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 141: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 142: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 143: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 144: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 145: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 146: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 147: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 148: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 149: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 150: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 151: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 152: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 153: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 154: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 155: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 156: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 157: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 158: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 159: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 160: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 161: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 162: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 163: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 164: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 165: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 166: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 167: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 168: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 169: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 170: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 171: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 172: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 173: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 174: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 175: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 176: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 177: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 178: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 179: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 180: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 181: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 182: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 183: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 184: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 185: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 186: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 187: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 188: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 189: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 190: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 191: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 192: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 193: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 194: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 195: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 196: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 197: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 198: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 199: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 200: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 201: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 202: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 203: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 204: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 205: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 206: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 207: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 208: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 209: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 210: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 211: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 212: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 213: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 214: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 215: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 216: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 217: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 218: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 219: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 220: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 221: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 222: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 223: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 224: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 225: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 226: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 227: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 228: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 229: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 230: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 231: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 232: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 233: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 234: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 235: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 236: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 237: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 238: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 239: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 240: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 241: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 242: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 243: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 244: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 245: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 246: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 247: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 248: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 249: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 250: Consulta finalizada.
# Finalizado lote 0 a 250. Esperando antes del siguiente lote...
# Procesando lote 250 a 500...
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 251: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 252: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 253: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 254: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 255: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 256: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 257: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 258: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 259: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 260: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 261: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 262: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 263: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 264: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 265: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 266: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 267: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 268: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 269: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 270: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 271: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 272: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 273: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 274: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 275: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 276: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 277: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 278: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 279: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 280: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 281: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 282: Consulta finalizada.
# Error en índice 283: [Errno 110] Connection timed out
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 283: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 284: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 285: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 286: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 287: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 288: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 289: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 290: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 291: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 292: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 293: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 294: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 295: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 296: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 297: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 298: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 299: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 300: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 301: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 302: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 303: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 304: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 305: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 306: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 307: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 308: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 309: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 310: Consulta finalizada.
# Error en índice 311: [Errno 110] Connection timed out
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 311: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 312: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 313: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 314: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 315: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 316: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 317: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 318: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 319: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 320: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 321: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 322: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 323: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 324: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 325: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 326: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 327: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 328: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 329: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 330: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 331: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 332: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 333: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 334: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 335: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 336: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 337: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 338: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 339: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 340: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 341: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 342: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 343: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 344: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 345: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 346: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 347: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 348: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 349: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 350: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 351: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 352: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 353: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 354: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 355: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 356: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 357: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 358: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 359: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 360: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 361: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 362: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 363: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 364: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 365: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 366: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 367: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 368: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 369: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 370: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 371: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 372: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 373: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 374: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 375: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 376: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 377: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 378: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 379: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 380: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 381: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 382: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 383: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 384: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 385: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 386: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 387: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 388: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 389: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 390: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 391: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 392: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 393: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 394: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 395: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 396: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 397: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 398: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 399: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 400: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 401: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 402: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 403: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 404: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 405: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 406: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 407: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 408: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 409: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 410: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 411: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 412: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 413: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 414: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 415: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 416: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 417: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 418: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 419: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 420: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 421: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 422: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 423: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 424: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 425: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 426: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 427: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 428: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 429: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 430: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 431: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 432: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 433: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 434: Consulta finalizada.
# Error en índice 435: [Errno 110] Connection timed out
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 435: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 436: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 437: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 438: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 439: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 440: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 441: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 442: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 443: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 444: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 445: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 446: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 447: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 448: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 449: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 450: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 451: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 452: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 453: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 454: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 455: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 456: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 457: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 458: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 459: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 460: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 461: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 462: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 463: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 464: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 465: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 466: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 467: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 468: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 469: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 470: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 471: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 472: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 473: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 474: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 475: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 476: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 477: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 478: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 479: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 480: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 481: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 482: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 483: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 484: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 485: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 486: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 487: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 488: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 489: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 490: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 491: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 492: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 493: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 494: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 495: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 496: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 497: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 498: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 499: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 500: Consulta finalizada.
# Finalizado lote 250 a 500. Esperando antes del siguiente lote...
# Procesando lote 500 a 750...
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 501: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 502: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 503: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 504: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 505: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 506: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 507: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 508: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 509: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 510: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 511: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 512: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 513: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 514: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 515: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 516: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 517: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 518: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 519: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 520: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 521: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 522: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 523: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 524: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 525: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 526: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 527: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 528: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 529: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 530: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 531: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 532: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 533: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 534: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 535: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 536: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 537: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 538: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 539: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 540: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 541: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 542: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 543: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 544: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 545: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 546: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 547: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 548: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 549: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 550: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 551: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 552: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 553: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 554: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 555: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 556: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 557: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 558: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 559: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 560: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 561: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 562: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 563: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 564: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 565: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 566: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 567: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 568: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 569: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 570: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 571: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 572: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 573: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 574: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 575: Consulta finalizada.
# ...
# Índice 7192: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7193: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7194: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7195: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7196: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7197: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7198: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7199: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7200: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7201: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7202: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7203: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7204: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7205: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7206: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7207: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7208: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7209: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7210: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7211: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7212: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7213: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7214: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7215: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7216: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7217: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7218: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7219: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7220: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7221: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7222: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7223: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7224: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7225: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7226: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7227: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7228: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7229: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7230: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7231: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7232: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7233: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7234: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7235: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7236: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7237: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7238: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7239: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7240: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7241: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7242: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7243: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7244: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7245: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7246: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7247: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7248: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7249: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7250: Consulta finalizada.
# Finalizado lote 7000 a 7250. Esperando antes del siguiente lote...
# Procesando lote 7250 a 7379...
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7251: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7252: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7253: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7254: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7255: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7256: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7257: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7258: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7259: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7260: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7261: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7262: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7263: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7264: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7265: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7266: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7267: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7268: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7269: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7270: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7271: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7272: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7273: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7274: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7275: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7276: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7277: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7278: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7279: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7280: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7281: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7282: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7283: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7284: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7285: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7286: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7287: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7288: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7289: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7290: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7291: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7292: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7293: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7294: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7295: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7296: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7297: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7298: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7299: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7300: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7301: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7302: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7303: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7304: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7305: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7306: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7307: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7308: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7309: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7310: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7311: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7312: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7313: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7314: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7315: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7316: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7317: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7318: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7319: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7320: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7321: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7322: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7323: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7324: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7325: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7326: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7327: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7328: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7329: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7330: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7331: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7332: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7333: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7334: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7335: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7336: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7337: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7338: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7339: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7340: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7341: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7342: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7343: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7344: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7345: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7346: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7347: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7348: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7349: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7350: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7351: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7352: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7353: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7354: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7355: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7356: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7357: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7358: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7359: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7360: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7361: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7362: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7363: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7364: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7365: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7366: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7367: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7368: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7369: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7370: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7371: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7372: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7373: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7374: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7375: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7376: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7377: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7378: Consulta finalizada.
# INFO: Query finished. [astroquery.utils.tap.core]
# Índice 7379: Consulta finalizada.
# Finalizado lote 7250 a 7379. Esperando antes del siguiente lote...
# Procesados 7379 exoplanetas.
# Encontradas 5325 estrellas en Gaia.

# %%
# View the first rows of the Gaia results
# print(gaia_stars.head())

# View additional details about the available columns
# print(gaia_stars.info())

# Explore details of the processed exoplanets
# print(subset_catalogue.head())

# %%
# exoplanet_index = 0
exoplanet_index = 12
exoplanet = subset_catalogue.iloc[exoplanet_index]
exoplanet_coord = SkyCoord(ra=exoplanet['ra'] * u.deg, dec=exoplanet['dec'] * u.deg, frame='icrs')

thresholds_arcsec = [2, 5, 10]  # search radii in arcseconds
thresholds_deg = [threshold * u.arcsec.to(u.deg) for threshold in thresholds_arcsec]

# Filter Gaia stars within the search radii
stars_in_radius = {}
for threshold_deg in thresholds_deg:
    stars_in_radius[threshold_deg] = gaia_stars[
        gaia_stars['ra'].between(exoplanet['ra'] - threshold_deg, exoplanet['ra'] + threshold_deg) &
        gaia_stars['dec'].between(exoplanet['dec'] - threshold_deg, exoplanet['dec'] + threshold_deg)
    ]

plt.figure(figsize=(8, 6))
plt.scatter(exoplanet['ra'], exoplanet['dec'], color='red', label='Exoplanet', s=100, zorder=5)

# Plot the matching Gaia stars in blue
first_iteration = True  # Flag to ensure 'Gaia Stars' label is added only once
for threshold_deg, threshold_arcsec in zip(thresholds_deg, thresholds_arcsec):
    stars = stars_in_radius[threshold_deg]
    # Plot all stars in blue
    if first_iteration:  # Only add the label in the first iteration
        plt.scatter(stars['ra'], stars['dec'], color='blue', alpha=1, s=50, label='Gaia Stars')
        first_iteration = False  # Disable label for subsequent iterations
    else:
        plt.scatter(stars['ra'], stars['dec'], color='blue', alpha=1, s=50)

    if threshold_arcsec == 2:
        circle_color = 'C0'  # Color for the 2 arcsec radius
    elif threshold_arcsec == 5:
        circle_color = 'C1'  # Color for the 5 arcsec radius
    else:
        circle_color = 'C2'  # Color for the 10 arcsec radius

    search_circle = Circle((exoplanet['ra'], exoplanet['dec']), radius=threshold_deg, color=circle_color, fill=False, linestyle='--', label=f'Search Radius ({threshold_arcsec} arcsec)')
    plt.gca().add_patch(search_circle)

plt.title(f'Exoplanet {exoplanet_index+1} and Nearby Gaia Stars with Different Search Radii')
plt.xlabel('RA (degrees)')
plt.ylabel('DEC (degrees)')
plt.legend(loc='upper left')  # Legend outside the plot
# plt.grid()
plt.axis('equal')
# plt.ylim(3.09585, 3.0959)
# plt.xlim(30.039, 30.0395)
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
exoplanet_indices = [7, 10, 12, 21]
thresholds_arcsec = [2, 5, 10]  # Search radii in arcseconds
thresholds_deg = [threshold * u.arcsec.to(u.deg) for threshold in thresholds_arcsec]

for ax, exoplanet_index in zip(axes.flatten(), exoplanet_indices):
    exoplanet = subset_catalogue.iloc[exoplanet_index]
    exoplanet_coord = SkyCoord(ra=exoplanet['ra'] * u.deg, dec=exoplanet['dec'] * u.deg, frame='icrs')

    # Filter Gaia stars within the search radii
    stars_in_radius = {}
    for threshold_deg in thresholds_deg:
        stars_in_radius[threshold_deg] = gaia_stars[
            gaia_stars['ra'].between(exoplanet['ra'] - threshold_deg, exoplanet['ra'] + threshold_deg) &
            gaia_stars['dec'].between(exoplanet['dec'] - threshold_deg, exoplanet['dec'] + threshold_deg)
        ]

    ax.scatter(exoplanet['ra'], exoplanet['dec'], color='red', label='Exoplanet', s=100, zorder=5)

    # Plot the matching Gaia stars in blue
    first_iteration = True
    for threshold_deg, threshold_arcsec in zip(thresholds_deg, thresholds_arcsec):
        stars = stars_in_radius[threshold_deg]
        if first_iteration:
            ax.scatter(stars['ra'], stars['dec'], color='blue', alpha=1, s=50, label='Gaia Stars')
            first_iteration = False
        else:
            ax.scatter(stars['ra'], stars['dec'], color='blue', alpha=1, s=50)

        if threshold_arcsec == 2:
            circle_color = 'C0'
        elif threshold_arcsec == 5:
            circle_color = 'C1'
        else:
            circle_color = 'C2'

        search_circle = Circle((exoplanet['ra'], exoplanet['dec']), radius=threshold_deg, color=circle_color, fill=False, linestyle='--', label=f'Search Radius ({threshold_arcsec} arcsec)')
        ax.add_patch(search_circle)

    ax.set_title(f'Exoplanet {exoplanet_index+1}')
    ax.set_xlabel('RA (degrees)')
    ax.set_ylabel('DEC (degrees)')
    ax.axis('equal')

# Add a common legend above the subplots
handles, labels = ax.get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=3, frameon=True, fontsize=10)
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, frameon=True, fontsize=10)

# Adjust layout for better spacing
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 9))
exoplanet_indices = [7, 10, 12, 21,46,76,82,96,99]
# exoplanet_indices = [47, 80, 64, 75]
thresholds_arcsec = [2, 5, 10]  # Search radii in arcseconds
thresholds_deg = [threshold * u.arcsec.to(u.deg) for threshold in thresholds_arcsec]

for ax, exoplanet_index in zip(axes.flatten(), exoplanet_indices):
    exoplanet = subset_catalogue.iloc[exoplanet_index]
    exoplanet_coord = SkyCoord(ra=exoplanet['ra'] * u.deg, dec=exoplanet['dec'] * u.deg, frame='icrs')

    # Filter Gaia stars within the search radii
    stars_in_radius = {}
    for threshold_deg in thresholds_deg:
        stars_in_radius[threshold_deg] = gaia_stars[
            gaia_stars['ra'].between(exoplanet['ra'] - threshold_deg, exoplanet['ra'] + threshold_deg) &
            gaia_stars['dec'].between(exoplanet['dec'] - threshold_deg, exoplanet['dec'] + threshold_deg)
        ]

    ax.scatter(exoplanet['ra'], exoplanet['dec'], color='red', label='Exoplanet', s=100, zorder=5)

    # Plot the matching Gaia stars in blue
    first_iteration = True
    for threshold_deg, threshold_arcsec in zip(thresholds_deg, thresholds_arcsec):
        stars = stars_in_radius[threshold_deg]
        if first_iteration:
            ax.scatter(stars['ra'], stars['dec'], color='blue', alpha=1, s=50, label='Gaia Stars')
            first_iteration = False
        else:
            ax.scatter(stars['ra'], stars['dec'], color='blue', alpha=1, s=50)

        if threshold_arcsec == 2:
            circle_color = 'C0'
        elif threshold_arcsec == 5:
            circle_color = 'C1'
        else:
            circle_color = 'C2'

        search_circle = Circle((exoplanet['ra'], exoplanet['dec']), radius=threshold_deg, color=circle_color, fill=False, linestyle='--', label=f'Search Radius ({threshold_arcsec} arcsec)')
        ax.add_patch(search_circle)

    ax.set_title(f'Exoplanet {exoplanet_index+1}', fontsize=14)

    if exoplanet_index + 1 in [8, 22, 83]:
        ax.set_ylabel('DEC (degrees)', fontsize=14, labelpad=10)

    if exoplanet_index + 1 in [83, 97, 100]:
        ax.set_xlabel('RA (degrees)', fontsize=14, labelpad=15)

    ax.axis('equal')
    ax.tick_params(axis='both', labelsize=12)


# Add a common legend above the subplots
handles, labels = ax.get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=3, frameon=True, fontsize=10)
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, frameon=True, fontsize=14)

# Adjust layout for better spacing
plt.tight_layout(rect=[0, 0, 1, 0.96])

fig.savefig('prueba.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
plotpars_2x3 = {'axes.linewidth': 1.,
                'axes.labelsize': 18,
                'xtick.labelsize': 11,
                'ytick.labelsize': 11,
                'legend.frameon': True,
                'legend.framealpha': 0.85,
                'legend.edgecolor': 'black',
                'legend.loc': 'best',
                'legend.fontsize': 14,
                'font.size': 12,
                'figure.figsize': (12.5,7.),
                'image.cmap': 'ocean_r',
                'figure.dpi': 300,
                # 'font.family': 'serif'
               }

# %%
plt.rcParams.update(plotpars_2x3)
fig, axes = plt.subplots(2, 3)
exoplanet_indices = [7, 10, 12, 21,46,99]
# exoplanet_indices = [47, 80, 64, 75]
thresholds_arcsec = [2, 5, 10]  # Search radii in arcseconds
thresholds_deg = [threshold * u.arcsec.to(u.deg) for threshold in thresholds_arcsec]

for ax, exoplanet_index in zip(axes.flatten(), exoplanet_indices):
    exoplanet = subset_catalogue.iloc[exoplanet_index]
    exoplanet_coord = SkyCoord(ra=exoplanet['ra'] * u.deg, dec=exoplanet['dec'] * u.deg, frame='icrs')

    # Filter Gaia stars within the search radii
    stars_in_radius = {}
    for threshold_deg in thresholds_deg:
        stars_in_radius[threshold_deg] = gaia_stars[
            gaia_stars['ra'].between(exoplanet['ra'] - threshold_deg, exoplanet['ra'] + threshold_deg) &
            gaia_stars['dec'].between(exoplanet['dec'] - threshold_deg, exoplanet['dec'] + threshold_deg)
        ]

    ax.scatter(exoplanet['ra'], exoplanet['dec'], color='red', label='Exoplanet', s=100, zorder=5)

    # Plot the matching Gaia stars in blue
    first_iteration = True
    for threshold_deg, threshold_arcsec in zip(thresholds_deg, thresholds_arcsec):
        stars = stars_in_radius[threshold_deg]
        if first_iteration:
            ax.scatter(stars['ra'], stars['dec'], color='blue', alpha=1, s=50, label='Gaia Stars')
            first_iteration = False
        else:
            ax.scatter(stars['ra'], stars['dec'], color='blue', alpha=1, s=50)

        if threshold_arcsec == 2:
            circle_color = 'C0'
        elif threshold_arcsec == 5:
            circle_color = 'C1'
        else:
            circle_color = 'C2'

        search_circle = Circle((exoplanet['ra'], exoplanet['dec']), radius=threshold_deg, color=circle_color, fill=False, linestyle='--', label=f'Search Radius ({threshold_arcsec} arcsec)')
        ax.add_patch(search_circle)

    ax.set_title(f'Exoplanet {exoplanet_index+1}', pad=15)

    if exoplanet_index + 1 in [8]:
        ax.set_ylabel('DEC (degrees)', labelpad=12.5)

    if exoplanet_index + 1 in [22]:
        ax.set_ylabel('DEC (degrees)', labelpad=10)

    if exoplanet_index + 1 in [22, 47, 100]:
        ax.set_xlabel('RA (degrees)', labelpad=15)

    ax.axis('equal')
    ax.tick_params(axis='both', labelsize=14)


# Add a common legend above the subplots
handles, labels = ax.get_legend_handles_labels()
# fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=3, frameon=True, fontsize=10)
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.06), ncol=3, frameon=True)

# Adjust layout for better spacing
plt.tight_layout(rect=[0, 0, 1, 0.96])

fig.savefig('prueba.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# Convert RA and DEC columns to SkyCoord objects with units
gaia_coords = SkyCoord(
    ra=gaia_stars['ra'].values * u.deg,
    dec=gaia_stars['dec'].values * u.deg,
    frame='icrs'
)

exoplanet_coords = SkyCoord(
    ra=subset_catalogue['ra'].values * u.deg,
    dec=subset_catalogue['dec'].values * u.deg,
    frame='icrs'
)

# Match coordinates between catalogs (Exoplanets and Gaia)
idx, sep2d, _ = match_coordinates_sky(exoplanet_coords, gaia_coords)

# Filter matches with separations less than or equal to 10 arcsec
match_mask = sep2d <= 10 * u.arcsec
matched_gaia_stars = gaia_stars.iloc[idx[match_mask]].reset_index(drop=True)
matched_exoplanets = subset_catalogue.iloc[match_mask].reset_index(drop=True)

plt.figure(figsize=(10, 6))
plt.scatter(gaia_stars['ra'], gaia_stars['dec'],color='blue', alpha=1, s=200, label='Gaia Stars')
plt.scatter(subset_catalogue['ra'], subset_catalogue['dec'],color='red', alpha=1, s=100, label='Exoplanets')
plt.scatter(matched_gaia_stars['ra'], matched_gaia_stars['dec'],color='green', alpha=1, s=30, label='Matched Gaia Stars')

plt.xlabel('RA (degrees)')
plt.ylabel('DEC (degrees)')
plt.title('Gaia Stars and Exoplanet Positions with Matches (<= 10 arcsec)')
plt.legend()
plt.gca().set_aspect('equal', adjustable='datalim')
plt.grid(alpha=0.3)
plt.show()

# %%
# Filter exoplanets with valid (non-NaN) values in the V, I, J, H, K filters
required_filters = ['mag_v', 'mag_i', 'mag_j', 'mag_h', 'mag_k']

# Check if the required columns exist in the catalogue
missing_columns = [col for col in required_filters if col not in exoplanet_catalogue.columns]
if missing_columns:
    print(f"The following columns are missing in the catalogue: {missing_columns}")
else:
    # Filter exoplanets with values in all required filters
    exoplanets_with_magnitudes = exoplanet_catalogue.dropna(subset=required_filters)
    print(f"Out of {len(exoplanet_catalogue)} exoplanets in the catalogue, "
          f"{len(exoplanets_with_magnitudes)} have valid values for all filters: {', '.join(required_filters)}.")
# Out:
# Out of 7343 exoplanets in the catalogue, 420 have valid values for all filters: mag_v, mag_i, mag_j, mag_h, mag_k.

# %%
# Count non-null numeric values for each filter
filter_counts = {col: exoplanet_catalogue[col].apply(pd.to_numeric, errors='coerce').notna().sum() for col in required_filters}

for col, count in filter_counts.items():
    print(f"{col}: {count} exoplanets with numeric values.")
# Out:
# mag_v: 3451 exoplanets with numeric values.
# mag_i: 584 exoplanets with numeric values.
# mag_j: 3839 exoplanets with numeric values.
# mag_h: 3820 exoplanets with numeric values.
# mag_k: 3177 exoplanets with numeric values.

# %%
# Adjust pandas settings to display all rows
pd.set_option('display.max_rows', None)

# Count non-NaN values per column
column_valid_counts = exoplanet_catalogue.notna().sum()

# Sort columns by the number of valid values
sorted_column_counts = column_valid_counts.sort_values(ascending=False)

# Display all columns sorted by the number of valid values
print("Columns sorted by the number of valid values (from highest to lowest):")
print(sorted_column_counts)

# Restore original settings to avoid displaying too many rows elsewhere in the code
pd.reset_option('display.max_rows')
# Out:
# Columns sorted by the number of valid values (from highest to lowest):
# name                          7343
# planet_status                 7343
# detection_type                7343
# updated                       7343
# ra                            7343
# dec                           7343
# publication                   7343
# discovered                    7334
# star_distance                 6992
# star_name                     6568
# star_mass                     6118
# orbital_period                6063
# star_teff                     5861
# star_radius                   5691
# star_teff_error_max           5562
# star_teff_error_min           5562
# orbital_period_error_min      5317
# orbital_period_error_max      5317
# star_metallicity              5191
# semi_major_axis               5059
# star_radius_error_max         5055
# star_radius_error_min         5055
# star_distance_error_min       5015
# star_distance_error_max       5015
# radius                        4927
# star_mass_error_min           4861
# star_mass_error_max           4861
# alternate_names               4828
# star_alternate_names          4490
# mass                          4385
# radius_error_max              4343
# radius_error_min              4343
# star_metallicity_error_min    4319
# star_metallicity_error_max    4319
# mag_j                         3839
# mag_h                         3820
# mass_error_max                3679
# mass_error_min                3679
# star_age                      3606
# star_sp_type                  3467
# mag_v                         3451
# star_age_error_max            3198
# star_age_error_min            3198
# mag_k                         3177
# semi_major_axis_error_min     3120
# semi_major_axis_error_max     3120
# eccentricity                  3091
# mass_measurement_type         3021
# tconj                         2651
# tconj_error_max               2584
# tconj_error_min               2584
# impact_parameter              2576
# impact_parameter_error_min    2548
# impact_parameter_error_max    2548
# inclination                   2419
# temp_calculated               2409
# eccentricity_error_max        2078
# eccentricity_error_min        2078
# radius_measurement_type       2058
# tzero_tr                      2018
# tzero_tr_error_max            1930
# tzero_tr_error_min            1930
# k                             1879
# k_error_max                   1823
# k_error_min                   1823
# inclination_error_max         1795
# inclination_error_min         1795
# omega                         1709
# omega_error_min               1581
# omega_error_max               1581
# temp_calculated_error_max     1439
# temp_calculated_error_min     1439
# mass_sini                     1392
# mass_sini_error_max           1136
# mass_sini_error_min           1136
# tperi                          849
# tperi_error_min                784
# tperi_error_max                784
# angular_distance               662
# mag_i                          584
# molecules                      140
# lambda_angle_error_min         134
# lambda_angle_error_max         134
# lambda_angle                   133
# temp_measured                  114
# star_detected_disc             109
# log_g                           56
# tzero_vr                        49
# tzero_tr_sec                    47
# tzero_vr_error_min              46
# tzero_tr_sec_error_max          46
# tzero_tr_sec_error_min          46
# tzero_vr_error_max              46
# geometric_albedo                18
# geometric_albedo_error_min      16
# geometric_albedo_error_max      16
# star_magnetic_field              5
# hot_point_lon                    4
# dtype: int64

# %%
# Adjust pandas settings to display all rows
pd.set_option('display.max_rows', None)

# Count valid numeric values per column
column_valid_counts = exoplanet_catalogue.apply(lambda col: col.apply(pd.to_numeric, errors='coerce').notna().sum())

# Sort columns by the number of valid values
sorted_column_counts = column_valid_counts.sort_values(ascending=False)

# Display all columns sorted by the number of valid numeric values
print("Columns sorted by the number of valid numeric values (from highest to lowest):")
print(sorted_column_counts)

# Restore original settings to avoid displaying too many rows elsewhere in the code
pd.reset_option('display.max_rows')
# Out:
# Columns sorted by the number of valid numeric values (from highest to lowest):
# ra                            7343
# dec                           7343
# discovered                    7334
# star_distance                 6992
# star_mass                     6118
# orbital_period                6063
# star_teff                     5861
# star_radius                   5691
# star_teff_error_min           5562
# star_teff_error_max           5562
# orbital_period_error_min      5317
# orbital_period_error_max      5317
# star_metallicity              5191
# semi_major_axis               5059
# star_radius_error_max         5055
# star_radius_error_min         5055
# star_distance_error_min       5015
# star_distance_error_max       5015
# radius                        4927
# star_mass_error_min           4861
# star_mass_error_max           4861
# mass                          4385
# radius_error_max              4343
# radius_error_min              4343
# star_metallicity_error_min    4319
# star_metallicity_error_max    4319
# mag_j                         3839
# mag_h                         3820
# mass_error_max                3679
# mass_error_min                3679
# star_age                      3606
# mag_v                         3451
# star_age_error_min            3198
# star_age_error_max            3198
# mag_k                         3177
# semi_major_axis_error_min     3120
# semi_major_axis_error_max     3120
# eccentricity                  3091
# tconj                         2651
# tconj_error_max               2584
# tconj_error_min               2584
# impact_parameter              2576
# impact_parameter_error_min    2548
# impact_parameter_error_max    2548
# inclination                   2419
# temp_calculated               2409
# eccentricity_error_min        2078
# eccentricity_error_max        2078
# tzero_tr                      2018
# tzero_tr_error_max            1930
# tzero_tr_error_min            1930
# k                             1879
# k_error_min                   1823
# k_error_max                   1823
# inclination_error_min         1795
# inclination_error_max         1795
# omega                         1709
# omega_error_min               1581
# omega_error_max               1581
# temp_calculated_error_max     1439
# temp_calculated_error_min     1439
# mass_sini                     1392
# mass_sini_error_max           1136
# mass_sini_error_min           1136
# tperi                          849
# tperi_error_min                784
# tperi_error_max                784
# angular_distance               662
# mag_i                          584
# lambda_angle_error_max         134
# lambda_angle_error_min         134
# lambda_angle                   133
# temp_measured                  114
# log_g                           56
# tzero_vr                        49
# tzero_tr_sec                    47
# tzero_vr_error_max              46
# tzero_vr_error_min              46
# tzero_tr_sec_error_min          46
# tzero_tr_sec_error_max          46
# star_alternate_names            34
# geometric_albedo                18
# geometric_albedo_error_max      16
# geometric_albedo_error_min      16
# hot_point_lon                    4
# star_magnetic_field              0
# star_detected_disc               0
# updated                          0
# planet_status                    0
# star_name                        0
# molecules                        0
# star_sp_type                     0
# publication                      0
# detection_type                   0
# mass_measurement_type            0
# radius_measurement_type          0
# alternate_names                  0
# name                             0
# dtype: int64

# %% [markdown]
# To filter stars in the case of multiple matches, we can compare the values of the following parameters with those of the host star listed on exoplanet.eu. The challenge is that since we don't have a parameter available for all exoplanets in the catalogue, we would need to filter incrementally using some of these parameters until we achieve the correct match for all possible exoplanets.
#
# - star_mass
# - star_teff
# - star_radius
# - star_metallicity
#
# - mag_j
# - mag_h
# - mag_v
# - mag_k

# %% [markdown]
# Let's abandon this method since the planets on exoplanet.eu are already cross-matched with their host stars. We'll rely on this work and won't duplicate it. Instead, we'll attempt to cross-match the catalog with Gaia directly using the host star identifier. We can continue using Python and Astroquery.

# %% [markdown]
# **IMPORTANT:** We do not consider epochs/proper motion corrections in these initial visualizations.
